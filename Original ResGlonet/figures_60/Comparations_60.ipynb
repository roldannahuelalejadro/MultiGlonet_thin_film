# %% [markdown]
# Para $\theta = 0$:

# %%
import numpy as np
import matplotlib.pyplot as plt

Flancos = np.linspace(400 , 700 , 102)

Error_0 =  [0.0030891603634107373, 0.0040961593382044656, 0.006357086254742986, 0.003307183097872443, 0.012468279400096366, 0.005298991383212177, 0.010576126259246645, 0.012106319621511683, 0.00878768091536336, 0.010439720339219987, 0.007237039338586176, 0.0055855513912600975, 0.029953601031938643, 0.038582021553697, 0.009169700883630625, 0.021179426364002024, 0.010441035231175084, 0.022860635168128737, 0.013530730762977538, 0.023721233929483852, 0.03807098663696487, 0.00793695778735551, 0.028721149033482645, 0.026566792335514674, 0.05259786778065517, 0.03249247447856713, 0.024552116845213686, 0.022974782170342576, 0.015522951259884543, 0.030271371626748388, 0.012838320535595247, 0.0647287635382212, 0.018080882333007857, 0.04275106864614408, 0.016320317728538595, 0.054387525364081986, 0.06680552032627064, 0.06961680679939443, 0.014165218282461272, 0.05640120706111427, 0.05673213114254148, 0.031898706165755165, 0.017761533553766418, 0.020282942510828142, 0.039658373340935665, 0.008726006117594188, 0.061448738671075004, 0.023710382428385916, 0.02701072469576063, 0.02192932109499436, 0.028833622976616954, 0.04803144738772132, 0.0567336282228056, 0.01579693003596931, 0.0725091474550282, 0.023059015346379774, 0.04622577024080513, 0.01690168711786905, 0.02026835318836298, 0.02790799659320769, 0.009687013727532869, 0.019016917105049446, 0.04016157931803297, 0.05465548733692322, 0.03431544431347307, 0.027031411521742942, 0.07468835536088295, 0.039361869801537566, 0.07154459900857027, 0.05971814044980871, 0.018721226049566986, 0.03475842583034283, 0.016433498149001902, 0.035572474450339106, 0.04933008404301178, 0.040247719534339324, 0.03582605729956845, 0.023795031665070635, 0.030701863594188823, 0.10486567492875651, 0.024478589100795894, 0.04775533538660028, 0.04116704215992714, 0.03595239226245411, 0.03219342123016501, 0.029644361340643438, 0.04217533624588121, 0.05156989902303481, 0.019705501654036194, 0.025490995466421994, 0.029317123989770044, 0.05815958798605881, 0.02442560892645816, 0.018360665681641755, 0.022827846083669598, 0.019098944567188473, 0.017083741879678472, 0.0170900095748409, 0.011529452614534695, 0.007345267440856089, 0.0001427385096743299, 0.00010489465414165046]
Error_30 =  [0.11180937, 0.18609037, 0.1737498, 0.1340922, 0.11580399, 0.15062827, 0.16864837, 0.15876095, 0.12005828, 0.15773856, 0.12908142, 0.10772375, 0.15951207, 0.05548546, 0.15562949, 0.1038304, 0.12197165, 0.12981713, 0.13274411, 0.08317917, 0.05526418, 0.10339934, 0.10643411, 0.11761428, 0.12924766, 0.10110386, 0.06579155, 0.09372834, 0.05925744, 0.11110199, 0.12584687, 0.09323732, 0.06185675, 0.10902861, 0.09553979, 0.09335108, 0.09458196, 0.09479225, 0.07079353, 0.06524813, 0.04378293, 0.0258439, 0.07264145, 0.03820836, 0.06219168, 0.05695044, 0.03310314, 0.06921838, 0.05413908, 0.04472266, 0.04383057, 0.04102456, 0.03919897, 0.03302078, 0.03591755, 0.02219042, 0.03897772, 0.03111393, 0.02673582, 0.02475837, 0.02249538, 0.05731366, 0.01956079, 0.02154055, 0.01719276, 0.05982088, 0.01470475, 0.01672782, 0.01747441, 0.01397106, 0.01582912, 0.01927175, 0.01201169, 0.02575423, 0.02506734, 0.02196449, 0.03637596, 0.08501353, 0.01671261, 0.04411404, 0.01575519, 0.02599133, 0.02695348, 0.05257512, 0.02071198, 0.02630565, 0.01611229, 0.02111252, 0.0234858, 0.03637753, 0.02105782, 0.01777107, 0.01857511, 0.02428915, 0.02809922, 0.0186626, 0.01774214, 0.01566333, 0.01160152, 0.00760356, 5.11315591e-08, 5.20367217e-08]
Error_60 =  [0.1668, 0.11941326, 0.12643376, 0.1074236, 0.13154317, 0.15112739, 0.18809741, 0.12289566, 0.12867904, 0.14155978, 0.16190672, 0.1576572, 0.11472215, 0.15125617, 0.1611784, 0.14975544, 0.09253179, 0.09211567, 0.14381597, 0.10917142, 0.13585808, 0.11035109, 0.08221823, 0.10509239, 0.10374266, 0.09906762, 0.06164857, 0.09428521, 0.08536108, 0.08894364, 0.03886938, 0.08713105, 0.11375478, 0.06847473, 0.09615492, 0.11833587, 0.07488554, 0.08874173, 0.08542816, 0.04011023, 0.07998097, 0.04614947, 0.03888703, 0.0624696, 0.05488682, 0.04711685, 0.06798901, 0.05099035, 0.06594146, 0.04044125, 0.01747232, 0.03023768, 0.03851006, 0.01792947, 0.03857012, 0.03692362, 0.03721454, 0.02083611, 0.02826871, 0.0224425, 0.02457024, 0.03598224, 0.01910964, 0.02462353, 0.02486401, 0.01718745, 0.02325577, 0.01374297, 0.03132286, 0.01345308, 0.03219187, 0.01439523, 0.01378436, 0.01455526, 0.02281827, 0.02150555, 0.01541749, 0.02198819, 0.01461205, 0.0137578, 0.01763547, 0.0186169, 0.01449527, 0.01984013, 0.02195674, 0.01692607, 0.03351979, 0.02464446, 0.02198673, 0.02978082, 0.02317369, 0.02256313, 0.0244228, 0.02293325, 0.01972085, 0.01499003, 0.01620366, 0.01517375, 0.01307278, 0.00739836, 5.15871919e-08, 5.15203148e-08]

plt.figure(figsize= (8, 6))
plt.plot(Flancos, Error_0, "o-", alpha = 0.7 ,label = r'Error en $\theta$ = 0'  )
plt.plot(Flancos, Error_30,"o-", alpha = 0.7 , label = r'Error en $\theta$ = 30')
plt.plot(Flancos, Error_60,"o-", alpha = 0.7 , label = r'Error en $\theta$ = 60')
plt.xlabel("Flanco ", fontsize = 15)
plt.ylabel('Error cuadrático minimo', fontsize = 15)
plt.legend(fontsize = 11)

# %%
import pandas as pd
import re


def extract_tensor_value_refindex(tensor_str):
    # Usar una expresión regular para buscar los números en el formato de tensor
    match = re.search(r'tensor\(\[\[(.*?)\]\], dtype=torch.float64\)', tensor_str)
    if match:
        return float(match.group(1))  # Convertir a float y devolver
    return None  # En caso de no encontrar un valor válido

def extract_tensor_valuethicknesses(tensor_str):
    # Usar una expresión regular para buscar los números en el formato de tensor
    match = re.search(r'tensor\(\[(.*?)\]\)', tensor_str)
    if match:
        return float(match.group(1))  # Convertir a float y devolver
    return None  # En caso de no encontrar un valor válido
data_ref_index = pd.read_csv('optimal_ref_idx_60.csv', header=None)
extracted_values = data_ref_index.applymap(lambda x: extract_tensor_value_refindex(x) if isinstance(x, str) else x)
ref_index = extracted_values.transpose()

data_thickness = pd.read_csv('optimal_thicknesses_60.csv', header=None)
extracted_values = data_thickness.applymap(lambda x: extract_tensor_valuethicknesses(x) if isinstance(x, str) else x)
thicknesses = extracted_values.transpose()

data_reflections = pd.read_csv('optimal_reflections_60.csv', header=None)
reflections = data_reflections.transpose()
# Out:
# /tmp/ipykernel_686/671353625.py:19: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   extracted_values = data_ref_index.applymap(lambda x: extract_tensor_value_refindex(x) if isinstance(x, str) else x)
# /tmp/ipykernel_686/671353625.py:23: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   extracted_values = data_thickness.applymap(lambda x: extract_tensor_valuethicknesses(x) if isinstance(x, str) else x)

# %%
valores_capas_1 = ref_index[0]
espesores_1 = thicknesses[0]

# Definir los valores y espesores de las capas para la segunda estructura
valores_capas_2 = ref_index[50]
espesores_2 = thicknesses[50]

# Definir los valores y espesores de las capas para la tercera estructura
valores_capas_3 = ref_index[99]
espesores_3 = thicknesses[99]

# Crear un colormap
colormap = plt.get_cmap('turbo')

# Definir el rango de valores
valor_min = 1
valor_max = 2.6

# Asignar colores a cada valor basado en el colormap
colores_1 = [colormap((valor - valor_min) / (valor_max - valor_min)) for valor in valores_capas_1]
colores_2 = [colormap((valor - valor_min) / (valor_max - valor_min)) for valor in valores_capas_2]
colores_3 = [colormap((valor - valor_min) / (valor_max - valor_min)) for valor in valores_capas_3]

# Crear la figura y el eje para todas las estructuras, con una relación de aspecto más ancha que alta
fig, (ax2, ax1) = plt.subplots(2, 1, figsize=(10, 6), gridspec_kw={'height_ratios': [2, 1]})

# Gráfico de error cuadrático mínimo en ax1
ax1.plot(Flancos, Error_60, "o-", alpha=0.8, label=r'Error en $\theta$ = 0', color = "green")
ax1.plot(Flancos[0], Error_60[0], "o", color="Red", label="Error iteración 0")
ax1.plot(Flancos[50], Error_60[50], "o", color="Red", label="Error iteración 50")
ax1.plot(Flancos[99], Error_60[99], "o", color="Red", label="Error iteración 100")
ax1.set_xlabel("Posición del flanco (nm)")
ax1.set_ylabel('Error cuadrático mínimo')
# ax1.legend()
# ax1.set_title('Error Cuadrático Mínimo')  # Tamaño 12x3 para que sea más ancho que alto

# Calcular la suma acumulada de los espesores para todas las estructuras
espesores_acumulados_1 = np.cumsum(espesores_1)
espesores_acumulados_2 = np.cumsum(espesores_2)
espesores_acumulados_3 = np.cumsum(espesores_3)

# Definir el ancho de las barras y la separación entre las estructuras
ancho_barra = 0.2
separacion = 0.3

# Graficar las barras para la primera estructura
for i in range(len(espesores_1)):
    ax2.bar(1 - ancho_barra - separacion, espesores_1[i], width=ancho_barra,
           bottom=espesores_acumulados_1[i] - espesores_1[i],
           color=colores_1[i], edgecolor='black', linewidth=0)

# Graficar las barras para la segunda estructura
for i in range(len(espesores_2)):
    ax2.bar(1, espesores_2[i], width=ancho_barra,
           bottom=espesores_acumulados_2[i] - espesores_2[i],
           color=colores_2[i], edgecolor='black', linewidth=0)

# Graficar las barras para la tercera estructura
for i in range(len(espesores_3)):
    ax2.bar(1 + ancho_barra + separacion, espesores_3[i], width=ancho_barra,
           bottom=espesores_acumulados_3[i] - espesores_3[i],
           color=colores_3[i], edgecolor='black', linewidth=0)

# Configurar las etiquetas y el título
ax2.set_ylabel(r'Espesor ($\mu$m)')
ax2.set_xticks([1 - ancho_barra - separacion, 1, 1 + ancho_barra + separacion])
ax2.set_xticklabels(['', '', ''])  # Nombres de las estructuras
# ax2.set_title('Comparación de Estructuras Fotónicas')

# Mostrar la barra de colores que representa el mapa de valores
sm = plt.cm.ScalarMappable(cmap=colormap, norm=plt.Normalize(valor_min, valor_max))
sm.set_array([])
fig.colorbar(sm, ax=ax2, label='Índice de refracción')

# Ajustar el diseño para evitar cortes en los márgenes
plt.tight_layout()
reflection_1 = reflections[0]
reflection_2 = reflections[50]
reflection_3 = reflections[100]

# Generar los valores de lambdas_k
lambdas_k = np.linspace(400, 700, 400)

# Definir los targets para cada conjunto
targets_1 = np.ones(400)
targets_2 = np.ones(400)
targets_3 = np.ones(400)

# Modificar los targets según los índices dados
targets_1[:0 * 4] = 0
targets_2[:50 * 4] = 0
targets_3[:100 * 4] = 0

# Crear la figura con tres subplots en formato de columna
fig, axs = plt.subplots(1, 3, figsize=(10, 3), sharex=True)

# Colores para cada gráfico
colors = ['blue', 'orange', 'green']

# Graficar las reflexiones en cada subplot con el mismo ylim
for ax, reflection, targets, color, title in zip(axs, 
                                                 [reflection_1, reflection_2, reflection_3], 
                                                 [targets_1, targets_2, targets_3], 
                                                 colors, 
                                                 ['Reflexión 1 y Objetivo', 'Reflexión 2 y Objetivo', 'Reflexión 3 y Objetivo']):
    ax.plot(lambdas_k, targets, ".-", color='red',alpha = 1, linewidth = 1 ,label='Objetivo')  # Formato "o-"
    ax.plot(lambdas_k, reflection, label='Simulado', color=color)
    ax.set_ylim(-0.1, 1.1)
    ax.set_ylabel('Reflectancia')
    ax.legend()

# Configurar el eje x compartido
axs[0].set_xlabel('Longitud de onda (nm)')
axs[1].set_xlabel('Longitud de onda (nm)')
axs[2].set_xlabel('Longitud de onda (nm)')


# Ajustar el diseño para evitar solapamientos
plt.tight_layout()

# Mostrar la gráfica
plt.show()

# %%
targets_2 = np.ones(400)
targets_2[:20 * 4] = 0
plt.plot(lambdas_k, targets_2, ".", color = "orange", alpha = 0.1 , linewidth = 0.3, label  = "Espectro objetivo")
plt.axvline(x=lambdas_k[20 * 4], color="red", alpha = 0.1, linestyle="--", label="Flanco")


targets_2 = np.ones(400)
targets_2[:50 * 4] = 0
plt.plot(lambdas_k, targets_2, ".", color = "orange", alpha = 0.5 , linewidth = 0.5, label  = "Espectro objetivo")
plt.axvline(x=lambdas_k[50 * 4], color="red", alpha = 0.3, linestyle="--", label="Flanco")

targets_2 = np.ones(400)
targets_2[:90 * 4] = 0
plt.plot(lambdas_k, targets_2, ".", color = "orange", alpha = 1 , linewidth = 1, label  = "Espectro objetivo")
plt.axvline(x=lambdas_k[90 * 4], color="red", alpha = 1, linestyle="--", label="Flanco")

plt.xlabel('Longitud de onda (nm)')
plt.ylabel("Reflectancia")

# plt.plot()
# Out:
# Text(0, 0.5, 'Reflectancia')

# %%
targets_2 = np.ones(400)
targets_2[:50 * 4] = 0
plt.plot(lambdas_k, targets_2, ".", color="orange", alpha=1, linewidth=1, label="Espectro objetivo")
plt.axvline(x=lambdas_k[50 * 4], color="red", alpha=1, linestyle="--")


plt.xlabel('Longitud de onda (nm)')
plt.ylabel("Reflectancia")
plt.legend()

plt.show()

# %%
# Generar una lista de posiciones de flanco y definir la cantidad de pasos
num_flancos = 10
flanco_positions = np.linspace(10, 100, num_flancos).astype(int)  # Genera 10 posiciones entre 10 y 100
alpha_values = np.linspace(0.1, 1, num_flancos)  # Transparencias desde 0.1 a 1
linewidth_values = np.linspace(0.3, 1, num_flancos)  # Grosores desde 0.3 a 1

# Iterar sobre los parámetros y generar los gráficos para cada flanco
for position, alpha, lw in zip(flanco_positions, alpha_values, linewidth_values):
    targets_2 = np.ones(400)
    targets_2[:position * 4] = 0
    plt.plot(lambdas_k, targets_2, ".", color="orange", alpha=alpha, linewidth=lw, label="Espectro objetivo" if position == flanco_positions[0] else "")
    plt.axvline(x=lambdas_k[position * 4], color="red", alpha=alpha, linestyle="--", label=f"Flanco {position}" if position == flanco_positions[0] else "")

# Configurar las etiquetas y mostrar la leyenda
plt.xlabel('Longitud de onda (nm)')
plt.ylabel("Reflectancia")
plt.legend()

# Mostrar el gráfico
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 12
#      10     targets_2[:position * 4] = 0
#      11     plt.plot(lambdas_k, targets_2, ".", color="orange", alpha=alpha, linewidth=lw, label="Espectro objetivo" if position == flanco_positions[0] else "")
# ---> 12     plt.axvline(x=lambdas_k[position * 4], color="red", alpha=alpha, linestyle="--", label=f"Flanco {position}" if position == flanco_positions[0] else "")
#      14 # Configurar las etiquetas y mostrar la leyenda
#      15 plt.xlabel('Longitud de onda (nm)')
#
# IndexError: index 400 is out of bounds for axis 0 with size 400
